# %% [markdown]
# # 서울시 교통사고 시각화

# %%
import pandas as pd

# %%
traffic_Seoul = pd.read_csv("../Data/newSeoul_2005_2019.csv")
traffic_Seoul.head()
# Out:
#      년도  월 자치구명  발생건수  사망자수  부상자수
# 0  2005  1  종로구    93     2   138
# 1  2005  2  종로구    84     3   125
# 2  2005  3  종로구   117     0   142
# 3  2005  4  종로구   138     2   212
# 4  2005  5  종로구   145     2   207

# %%
# 2019년 데이터만 추출하기
traffic_Seoul_2019 = traffic_Seoul[traffic_Seoul['년도'] == 2019]

# %%
# index 정리하기
traffic_Seoul_2019.reset_index(drop=True, inplace=True)
traffic_Seoul_2019
# Out:
#        년도   월 자치구명  발생건수  사망자수  부상자수
# 0    2019   1  종로구    87     1   125
# 1    2019   2  종로구    66     1    84
# 2    2019   3  종로구    87     2   122
# 3    2019   4  종로구    85     0   131
# 4    2019   5  종로구   112     1   158
# ..    ...  ..  ...   ...   ...   ...
# 295  2019   8  강동구   127     2   175
# 296  2019   9  강동구    98     2   137
# 297  2019  10  강동구   108     1   144
# 298  2019  11  강동구   146     0   199
# 299  2019  12  강동구   108     1   131
#
# [300 rows x 6 columns]

# %%
traffic_Seoul_2019.set_index('자치구명', inplace=True)
traffic_Seoul_2019
# Out:
#         년도   월  발생건수  사망자수  부상자수
# 자치구명
# 종로구   2019   1    87     1   125
# 종로구   2019   2    66     1    84
# 종로구   2019   3    87     2   122
# 종로구   2019   4    85     0   131
# 종로구   2019   5   112     1   158
# ...    ...  ..   ...   ...   ...
# 강동구   2019   8   127     2   175
# 강동구   2019   9    98     2   137
# 강동구   2019  10   108     1   144
# 강동구   2019  11   146     0   199
# 강동구   2019  12   108     1   131
#
# [300 rows x 5 columns]

# %%
import numpy as np

# %%
# 자치구별 발생건수, 사망자수, 부상자수 집계하기
#traffic_analysis = traffic_Seoul_2019[['발생건수','부상자수','사망자수']].groupby('자치구명').sum()
traffic_analysis = pd.pivot_table(traffic_Seoul_2019[['발생건수','부상자수','사망자수']], index='자치구명', aggfunc=np.sum)
traffic_analysis.head()
# Out:
#       발생건수  부상자수  사망자수
# 자치구명
# 강남구   3722  5182    14
# 강동구   1414  1910    11
# 강북구   1277  1706     7
# 강서구   1829  2491    20
# 관악구   1363  1755    10

# %%
# 위도, 경도 데이터 불러오기
seoul_limit = pd.read_csv("../Data/seoul.csv", encoding="euc-Kr")
seoul_limit.columns = ['자치구명','lon','lat']
seoul_limit.head()
# Out:
#   자치구명       lon       lat
# 0  강남구  127.0475  37.51731
# 1  강동구  127.1238  37.53013
# 2  강북구  127.0255  37.63975
# 3  관악구  126.9515  37.47834
# 4  구로구  126.8875  37.49547

# %%
# traffic_Seoul_2019와 seoul_limit 병합하기

data_result = pd.merge(traffic_analysis, seoul_limit, on='자치구명')
data_result.head()
# Out:
#   자치구명  발생건수  부상자수  사망자수       lon       lat
# 0  강남구  3722  5182    14  127.0475  37.51731
# 1  강동구  1414  1910    11  127.1238  37.53013
# 2  강북구  1277  1706     7  127.0255  37.63975
# 3  강서구  1829  2491    20  126.8496  37.55094
# 4  관악구  1363  1755    10  126.9515  37.47834

# %%
data_result.tail()
# Out:
#    자치구명  발생건수  부상자수  사망자수       lon       lat
# 20  용산구  1187  1614    10  126.9904  37.53254
# 21  은평구  1119  1464     7  126.9292  37.60278
# 22  종로구  1133  1559     6  126.9793  37.57323
# 23   중구  1184  1615     5  127.0032  37.55273
# 24  중랑구  1620  2122    12  127.0928  37.60652

# %%
# folium은 int를 읽지못함 float만 가능
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구명    25 non-null     object
#  1   발생건수    25 non-null     int64
#  2   부상자수    25 non-null     int64
#  3   사망자수    25 non-null     int64
#  4   lon     25 non-null     float64
#  5   lat     25 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
# folium을 사용하기 위해 int를 float로 변환해야 한다.

data_result[['발생건수','부상자수','사망자수']] = data_result[['발생건수','부상자수','사망자수']].astype(float)

# %%
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구명    25 non-null     object
#  1   발생건수    25 non-null     float64
#  2   부상자수    25 non-null     float64
#  3   사망자수    25 non-null     float64
#  4   lon     25 non-null     float64
#  5   lat     25 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.9+ KB

# %% [markdown]
# ### 자치구의 구청을 표시하기

# %%
import folium

# %%
map = folium.Map(
    location=[37.5502, 126.982],
    zoom_start=11,
    
)
# 자치구별 교통사고 발생건수를 표시하기(Marker)

# for n in data_result.index:
#    folium.Marker([data_result['lat'][n],data_result['lon'][n]],
#                   popup=data_result['자치구명'][n]
#                   ).add_to(map)
#    folium.CircleMarker(
#    [data_result['lat'][n],data_result['lon'][n]],
#    radius=data_result['발생건수'][n] / 100,  # 원의 반지름
#    color = 'cornflowerblue',
#    fill = False,
#    fill_color='cornflowerblue',
#    fill_opacity=0.3,
#    ).add_to(map)

# map

# %% [markdown]
# # 자치구별 교통사고 사망건수를 표시하기

# %%
for n in data_result.index:
    folium.Marker([data_result['lat'][n],data_result['lon'][n]],
                popup=data_result['자치구명'][n]
                ).add_to(map)
    folium.CircleMarker(
        [data_result['lat'][n],data_result['lon'][n]],
        radius=data_result['사망자수'][n] * 1.9,
        color = 'red',
        fill = False,
        fill_color='red',
        fill_opacity=0.3,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42b9306003057c24a76fa4a994f12a15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42b9306003057c24a76fa4a994f12a15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_42b9306003057c24a76fa4a994f12a15 = L.map(
#                 &quot;map_42b9306003057c24a76fa4a994f12a15&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71ef567745a4a04aa265ee13b8d0194c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42b9306003057c24a76fa4a994f12a15);
#
#
#             var marker_c90f64fe4b3f580b047f45f25617038d = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_42b9306003057c24a76fa4a994f12a15);
#
#
#         var popup_11cf5fee198b835e33c1a9647add44b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0e927ae42011d5216ed7941eae8d8f50 = $(`&lt;div id=&quot;html_0e927ae42011d5216ed7941eae8d8f50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_11cf5fee198b835e33c1a9647add44b8.setContent(html_0e927ae42011d5216ed7941eae8d8f50);
#
#
#         marker_c90f64fe4b3f580b047f45f25617038d.bindPopup(popup_11cf5fee198b835e33c1a9647add44b8)
#         ;
#
#
#
#
#             var circle_marker_eb391239e39108dfc7fa42b67b06e3d5 = L.circleMarker(
#                 [37.51731, 127.0475],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 26.599999999999998, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42b9306003057c24a76fa4a994f12a15);
#
#
#             var marker_5fd9f513c4c449c3a6cbc6927feb5e08 = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_42b9306003057c24a76fa4a994f12a15);
#
#
#         var popup_09df7fa056f103fe71f9afe2c4f7f50e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_56ec247e2e10ef771225537f22df60fd = $(`&lt;div id=&quot;html_56ec247e2e10ef771225537f22df60fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구&lt;/div&gt;`)[0];
#             popup_09df7fa056f103fe71f9afe2c4f7f50e.setContent(html_56ec247e2e10ef771225537f22df60fd);
#
#
#         marker_5fd9f513c4c449c3a6cbc6927feb5e08.bindPopup(popup_09df7fa056f103fe71f9afe2c4f7f50e)
#         ;
#
#
#
#
#             var circle_marker_4d24587332d8713acddbc29dc16d6429 = L.circleMarker(
#                 [37.53013, 127.1238],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42b9306003057c24a76fa4a994f12a15);
#
#
#             var marker_1ef29d21240748bb4feab066106ffaba = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_42b9306003057c24a76fa4a994f12a15);
#
#
#         var popup_3af976b3fa9ec61f9faae4e96cc2c3a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e0d20942f7535f3cf531a8ace881ae1e = $(`&lt;div id=&quot;html_e0d20942f7535f3cf531a8ace881ae1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북구&lt;/div&gt;`)[0];
#             popup_3af976b3fa9ec61f9faae4e96cc2c3a5.setContent(html_e0d20942f7535f3cf531a8ace881ae1e);
#
#
#         marker_1ef29d21240748bb4feab066106ffaba.bindPopup(popup_3af976b3fa9ec61f9faae4e96cc2c3a5)
#         ;
#
#
#
#
#             var circle_marker_9177308d9734fdc9e2e2fbf2e3cdb263 = L.circleMarker(
#                 [37.63975, 127.0255],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.299999999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42b9306003057c24a76fa4a

# %%
data_result.sort_values('사망자수', inplace=True)
data_result.reset_index(drop=True, inplace=True)
data_result
# Out:
#     자치구명    발생건수    부상자수  사망자수       lon       lat
# 0    광진구   973.0  1316.0   3.0  127.0824  37.53862
# 1    도봉구   852.0  1163.0   4.0  127.0478  37.66873
# 2    동작구  1406.0  2021.0   5.0  126.9393  37.51243
# 3     중구  1184.0  1615.0   5.0  127.0032  37.55273
# 4    종로구  1133.0  1559.0   6.0  126.9793  37.57323
# 5    마포구  1494.0  2123.0   7.0  126.9016  37.56631
# 6    강북구  1277.0  1706.0   7.0  127.0255  37.63975
# 7    은평구  1119.0  1464.0   7.0  126.9292  37.60278
# 8    노원구  1703.0  2302.0   8.0  127.0565  37.65437
# 9    성북구  1509.0  2007.0   8.0  127.0167  37.58936
# 10   금천구   920.0  1353.0   9.0  126.8957  37.45708
# 11   용산구  1187.0  1614.0  10.0  126.9904  37.53254
# 12   관악구  1363.0  1755.0  10.0  126.9515  37.47834
# 13   강동구  1414.0  1910.0  11.0  127.1238  37.53013
# 14  영등포구  2439.0  3451.0  11.0  126.8966  37.52582
# 15   양천구  1506.0  2085.0  11.0  126.8666  37.51702
# 16   중랑구  1620.0  2122.0  12.0  127.0928  37.60652
# 17   송파구  2892.0  4003.0  13.0  127.1059  37.51448
# 18   구로구  1529.0  2096.0  13.0  126.8875  37.49547
# 19   성동구  1091.0  1439.0  13.0  127.0368  37.56346
# 20   서초구  2418.0  3530.0  14.0  127.0330  37.48400
# 21  서대문구  1113.0  1609.0  14.0  126.9368  37.57908
# 22   강남구  3722.0  5182.0  14.0  127.0475  37.51731
# 23  동대문구  1565.0  1988.0  15.0  127.0396  37.57452
# 24   강서구  1829.0  2491.0  20.0  126.8496  37.55094

# %%
folium.Marker([data_result['lat'][0],data_result['lon'][0]],
            popup=data_result['자치구명'][0]
            ).add_to(map)
folium.CircleMarker(
    [data_result['lat'][0],data_result['lon'][0]],
    radius=data_result['사망자수'][0] * 1.9,
    color = 'red',
    fill = False,
    fill_color='red',
    fill_opacity=0.3,
).add_to(map)

folium.Marker([data_result['lat'][24],data_result['lon'][24]],
            popup=data_result['자치구명'][24]
            ).add_to(map)
folium.CircleMarker(
    [data_result['lat'][24],data_result['lon'][24]],
    radius=data_result['사망자수'][24] * 1.9,
    color = 'red',
    fill = False,
    fill_color='red',
    fill_opacity=0.3,
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_912c3e56fb2c934fab13537202a6b9e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_912c3e56fb2c934fab13537202a6b9e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_912c3e56fb2c934fab13537202a6b9e3 = L.map(
#                 &quot;map_912c3e56fb2c934fab13537202a6b9e3&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5751b351fe60f5b200733e31412801e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_912c3e56fb2c934fab13537202a6b9e3);
#
#
#             var marker_666cc32ec9208ba8c0f337afa99102fb = L.marker(
#                 [37.53862, 127.0824],
#                 {}
#             ).addTo(map_912c3e56fb2c934fab13537202a6b9e3);
#
#
#         var popup_59a1d2e895ab5f381b200ce814ff04c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2143e2f59d1c9a5ed7b78ea3fddc397c = $(`&lt;div id=&quot;html_2143e2f59d1c9a5ed7b78ea3fddc397c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&gt;`)[0];
#             popup_59a1d2e895ab5f381b200ce814ff04c8.setContent(html_2143e2f59d1c9a5ed7b78ea3fddc397c);
#
#
#         marker_666cc32ec9208ba8c0f337afa99102fb.bindPopup(popup_59a1d2e895ab5f381b200ce814ff04c8)
#         ;
#
#
#
#
#             var circle_marker_7ef76fcfa020742fdc1301ab2c4f81cf = L.circleMarker(
#                 [37.53862, 127.0824],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.699999999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_912c3e56fb2c934fab13537202a6b9e3);
#
#
#             var marker_64c6a12d71ff26d26bae3aa0891573d7 = L.marker(
#                 [37.53862, 127.0824],
#                 {}
#             ).addTo(map_912c3e56fb2c934fab13537202a6b9e3);
#
#
#         var popup_46a4a6395447c45d6e5c1d01138f7323 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_25bc4ccfc96b6cfdb839589524512185 = $(`&lt;div id=&quot;html_25bc4ccfc96b6cfdb839589524512185&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&gt;`)[0];
#             popup_46a4a6395447c45d6e5c1d01138f7323.setContent(html_25bc4ccfc96b6cfdb839589524512185);
#
#
#         marker_64c6a12d71ff26d26bae3aa0891573d7.bindPopup(popup_46a4a6395447c45d6e5c1d01138f7323)
#         ;
#
#
#
#
#             var circle_marker_821e45070ed3841187cbe024e5072b16 = L.circleMarker(
#                 [37.53862, 127.0824],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.699999999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_912c3e56fb2c934fab13537202a6b9e3);
#
#
#             var marker_481b0b7725e14030931500e880f5e78a = L.marker(
#                 [37.55094, 126.8496],
#                 {}
#             ).addTo(map_912c3e56fb2c934fab13537202a6b9e3);
#
#
#         var popup_19a292f7fdd2649fbf4c93b3e919873a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c9ee207b290fa23c43adaba5c5a66a0a = $(`&lt;div id=&quot;html_c9ee207b290fa23c43adaba5c5a66a0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강서구&lt;/div&gt;`)[0];
#             popup_19a292f7fdd2649fbf4c93b3e919873a.setContent(html_c9ee207b290fa23c43adaba5c5a66a0a);
#
#
#         marker_481b0b7725e14030931500e880f5e78a.bindPopup(popup_19a292f7fdd2649fbf4c93b3e919873a)
#         ;
#
#
#
#
#             var circle_marker_b273c9342cdad9f6542d83ba6cebe33c = L.circleMarker(
#                 [37.55094, 126.8496],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 38.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_912c3e56fb2c934fab1353720

# %%
# Out:
# 0     37.53862
# 24    37.55094
# Name: lat, dtype: float64
