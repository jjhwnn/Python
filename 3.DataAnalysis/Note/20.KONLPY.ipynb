# %%
# !pip install tweepy==3.10.0
# Out:
# Collecting tweepy==3.10.0
#   Downloading tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tweepy==3.10.0) (1.16.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tweepy==3.10.0) (2.26.0)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.5/151.5 KB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2021.5.30)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: PySocks, oauthlib, requests-oauthlib, tweepy
# Successfully installed PySocks-1.7.1 oauthlib-3.2.0 requests-oauthlib-1.3.1 tweepy-3.10.0
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ---------------------------------------- 19.4/19.4 MB 2.2 MB/s eta 0:00:00
# Collecting lxml>=4.1.0
#   Downloading lxml-4.9.1-cp39-cp39-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 1.8 MB/s eta 0:00:00
# Collecting numpy>=1.6
#   Downloading numpy-1.23.1-cp39-cp39-win_amd64.whl (14.7 MB)
#      ---------------------------------------- 14.7/14.7 MB 1.8 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp39-cp39-win_amd64.whl (344 kB)
#      -------------------------------------- 344.7/344.7 KB 1.8 MB/s eta 0:00:00
# Installing collected packages: numpy, lxml, JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0 lxml-4.9.1 numpy-1.23.1
#   WARNING: The script f2py.exe is installed in 'C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
kkma.sentences('나는 자랑스러운 태극기 앞에 자유롭고 정의로운 대한민국의 무궁한 영광을 위하여 충성을 다 할 것을 굳게 다짐 합니다.')
# Out:
# ['나는 자랑스러운 태극기 앞에 자유롭고 정의로운 대한민국의 무궁한 영광을 위하여 충성을 다 할 것을 굳게 다짐 합니다.']

# %%
# 명사 알려주는 메서드
kkma.nouns('나는 자랑스러운 태극기 앞에 자유롭고 정의로운 대한민국의 무궁한 영광을 위하여 충성을 다 할 것을 굳게 다짐 합니다.')
# Out:
# ['나', '자랑', '태극기', '앞', '자유', '정의', '대한', '대한민국', '민국', '무궁', '영광', '충성', '다짐']

# %%
# 명사, 동사, ... 알려주는 메서드
kkma.pos('나는 자랑스러운 태극기 앞에 자유롭고 정의로운 대한민국의 무궁한 영광을 위하여 충성을 다 할 것을 굳게 다짐 합니다.')
# Out:
# [('나', 'NP'),
#  ('는', 'JX'),
#  ('자랑', 'NNG'),
#  ('스럽', 'XSA'),
#  ('ㄴ', 'ETD'),
#  ('태극기', 'NNG'),
#  ('앞', 'NNG'),
#  ('에', 'JKM'),
#  ('자유', 'NNG'),
#  ('롭', 'XSA'),
#  ('고', 'ECE'),
#  ('정의', 'NNG'),
#  ('롭', 'XSA'),
#  ('ㄴ', 'ETD'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('무궁', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('영광', 'NNG'),
#  ('을', 'JKO'),
#  ('위하', 'VV'),
#  ('여', 'ECS'),
#  ('충성', 'NNG'),
#  ('을', 'JKO'),
#  ('다', 'MAG'),
#  ('하', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('것', 'NNB'),
#  ('을', 'JKO'),
#  ('굳', 'VA'),
#  ('게', 'ECD'),
#  ('다짐', 'NNG'),
#  ('하', 'VV'),
#  ('ㅂ니다', 'EFN'),
#  ('.', 'SF')]

# %%
from konlpy.tag import Hannanum
hannanum = Hannanum()

# %%
hannanum.nouns('나는 자랑스러운 태극기 앞에 자유롭고 정의로운 대한민국의 무궁한 영광을 위하여 충성을 다 할 것을 굳게 다짐 합니다.')
# Out:
# ['나', '자랑', '태극기', '앞', '자유', '정의로운', '대한민국', '무궁한', '영광', '충성', '것', '다짐']

# %%
# 형태소 분류
hannanum.morphs('나는 자랑스러운 태극기 앞에 자유롭고 정의로운 대한민국의 무궁한 영광을 위하여 충성을 다 할 것을 굳게 다짐 합니다.')
# Out:
# ['나',
#  '는',
#  '자랑',
#  '스럽',
#  '은',
#  '태극기',
#  '앞',
#  '에',
#  '자유',
#  '롭',
#  '고',
#  '정의로운',
#  '대한민국',
#  '의',
#  '무궁한',
#  '영광',
#  '을',
#  '위하',
#  '어',
#  '충성',
#  '을',
#  '다',
#  '하',
#  'ㄹ',
#  '것',
#  '을',
#  '굳',
#  '게',
#  '다짐',
#  '하',
#  'ㅂ니다',
#  '.']

# %%
hannanum.pos('나는 자랑스러운 태극기 앞에 자유롭고 정의로운 대한민국의 무궁한 영광을 위하여 충성을 다 할 것을 굳게 다짐 합니다.')
# Out:
# [('나', 'N'),
#  ('는', 'J'),
#  ('자랑', 'N'),
#  ('스럽', 'X'),
#  ('은', 'E'),
#  ('태극기', 'N'),
#  ('앞', 'N'),
#  ('에', 'J'),
#  ('자유', 'N'),
#  ('롭', 'X'),
#  ('고', 'E'),
#  ('정의로운', 'N'),
#  ('대한민국', 'N'),
#  ('의', 'J'),
#  ('무궁한', 'N'),
#  ('영광', 'N'),
#  ('을', 'J'),
#  ('위하', 'P'),
#  ('어', 'E'),
#  ('충성', 'N'),
#  ('을', 'J'),
#  ('다', 'M'),
#  ('하', 'P'),
#  ('ㄹ', 'E'),
#  ('것', 'N'),
#  ('을', 'J'),
#  ('굳', 'P'),
#  ('게', 'E'),
#  ('다짐', 'N'),
#  ('하', 'P'),
#  ('ㅂ니다', 'E'),
#  ('.', 'S')]

# %%
from konlpy.tag import Okt

t=Okt()

# %%
t.nouns('나는 자랑스러운 태극기 앞에 자유롭고 정의로운 대한민국의 무궁한 영광을 위하여 충성을 다 할 것을 굳게 다짐 합니다.')
# Out:
# ['나', '태극기', '앞', '자유', '정의', '대한민국', '무궁', '영광', '위', '충성', '것', '다짐']

# %%
t.pos('나는 자랑스러운 태극기 앞에 자유롭고 정의로운 대한민국의 무궁한 영광을 위하여 충성을 다 할 것을 굳게 다짐 합니다.')
# Out:
# [('나', 'Noun'),
#  ('는', 'Josa'),
#  ('자랑스러운', 'Adjective'),
#  ('태극기', 'Noun'),
#  ('앞', 'Noun'),
#  ('에', 'Josa'),
#  ('자유', 'Noun'),
#  ('롭고', 'Josa'),
#  ('정의', 'Noun'),
#  ('로운', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('무궁', 'Noun'),
#  ('한', 'Josa'),
#  ('영광', 'Noun'),
#  ('을', 'Josa'),
#  ('위', 'Noun'),
#  ('하여', 'Verb'),
#  ('충성', 'Noun'),
#  ('을', 'Josa'),
#  ('다', 'Adverb'),
#  ('할', 'Verb'),
#  ('것', 'Noun'),
#  ('을', 'Josa'),
#  ('굳게', 'Adjective'),
#  ('다짐', 'Noun'),
#  ('합니다', 'Verb'),
#  ('.', 'Punctuation')]
