# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
# pandas
import pandas as pd
import time

# %%
# Chrome Browser와 Chrome Driver Version 확인
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
driver.get('https://www.pizzaalvolo.co.kr/quick/findstore')
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.53/chromedriver] found in cache
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_16237/3078077070.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_16237/3078077070.py in <module>
#       1 # Chrome Browser와 Chrome Driver Version 확인
#       2 chrome_options = webdriver.ChromeOptions()
# ----> 3 driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
#       4 driver.get('https://www.pizzaalvolo.co.kr/quick/findstore')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67             service = Service(executable_path, port, service_args, service_log_path)
#      68
# ---> 69         super().__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      70                          port, options,
#      71                          service_args, desired_capabilities,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      90
#      91         try:
# ---> 92             super().__init__(
#      93                 command_executor=ChromiumRemoteConnection(
#      94                     remote_server_addr=self.service.service_url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     275         self._authenticator_id = None
#     276         self.start_client()
# --> 277         self.start_session(capabilities, browser_profile)
#     278
#     279     def __repr__(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     368         w3c_caps = _make_w3c_caps(capabilities)
#     369         parameters = {"capabilities": w3c_caps}
# --> 370         response = self.execute(Command.NEW_SESSION, parameters)
#     371         if 'sessionId' not in response:
#     372             response = response['value']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: failed to write prefs file
# Stacktrace:
# 0   chromedriver                        0x000000010dbeb079 chromedriver + 4444281
# 1   chromedriver                        0x000000010db77403 chromedriver + 3970051
# 2   chromedriver                        0x000000010d812038 chromedriver + 409656
# 3   chromedriver                        0x000000010d838140 chromedriver + 565568
# 4   chromedriver                        0x000000010d838376 chromedriver + 566134
# 5   chromedriver                        0x000000010d833dd2 chromedriver + 548306
# 6   chromedriver                        0x000000010d831836 chromedriver + 538678
# 7   chromedriver                        0x000000010d86b44a chromedriver + 775242
# 8   chromedriver                        0x000000010d865683 chromedriver + 751235
# 9   chromedriver                        0x000000010d83ba45 chromedriver + 580165
# 10  chromedriver                        0x000000010d83ca95 chromedriver + 584341
# 11  chromedriver                        0x000000010dbbc55d chromedriver + 4253021
# 12  chromedriver                        0x000000010dbc13a1 chromedriver + 4273057
# 13  chromedriver                        0x000000010dbc616f chromedriver + 4292975
# 14  chromedriver                        0x000000010dbc1dea chromedriver + 4275690
# 15  chromedriver                        0x000000010db9b54f chromedriver + 4117839
# 16  chromedriver                        0x000000010dbdbed8 chromedriver + 4382424
# 17  chromedriver                        0x000000010dbdc05f chromedriver + 4382815
# 18  chromedriver                        0x000000010dbf28d5 chromedriver + 4475093
# 19  libsystem_pthread.dylib             0x00007ff8046214f4 _pthread_start + 125
# 20  libsystem_pthread.dylib             0x00007ff80461d00f thread_start + 15

# %%
largeBtns = driver.find_elements(By.CSS_SELECTOR, '.area-name-select-left option')
df = pd.DataFrame(columns=['name', 'address'])

for largeBtn in largeBtns:
    largeBtn.click()
    time.sleep(1)

    smallBtns = driver.find_elements(By.CSS_SELECTOR, '.area-name-select-right option')
    if len(smallBtns) == 1:
        smallDf = pd.DataFrame(columns=['name', 'address'])
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        nameList = soup.select('.chain-title')
        addressList = soup.select('.chain-address')

        for i in range(len(nameList)):
            smallDf.loc[i] = [nameList[i].text, addressList[i].text]
        df = df.append(smallDf)

    else:
        for smallBtn in smallBtns:
            smallBtn.click()
            time.sleep(1)

            smallDf = pd.DataFrame(columns=['name', 'address'])
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')

            nameList = soup.select('.chain-title')
            addressList = soup.select('.chain-address')

            for i in range(len(nameList)):
                smallDf.loc[i] = [nameList[i].text, addressList[i].text]
            df = df.append(smallDf)
 

df.to_csv('starbucks2.csv', encoding='utf-8', mode='w', index=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.53/chromedriver] found in cache
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_16237/3524893049.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_16237/3524893049.py in <module>
#       1 # Chrome Browser와 Chrome Driver Version 확인
#       2 chrome_options = webdriver.ChromeOptions()
# ----> 3 driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
#       4 driver.get('https://www.pizzaalvolo.co.kr/quick/findstore')
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67             service = Service(executable_path, port, service_args, service_log_path)
#      68
# ---> 69         super().__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      70                          port, options,
#      71                          service_args, desired_capabilities,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      90
#      91         try:
# ---> 92             super().__init__(
#      93                 command_executor=ChromiumRemoteConnection(
#      94                     remote_server_addr=self.service.service_url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     275         self._authenticator_id = None
#     276         self.start_client()
# --> 277         self.start_session(capabilities, browser_profile)
#     278
#     279     def __repr__(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     368         w3c_caps = _make_w3c_caps(capabilities)
#     369         parameters = {"capabilities": w3c_caps}
# --> 370         response = self.execute(Command.NEW_SESSION, parameters)
#     371         if 'sessionId' not in response:
#     372             response = response['value']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: failed to write prefs file
# Stacktrace:
# 0   chromedriver                        0x000000010485b079 chromedriver + 4444281
# 1   chromedriver                        0x00000001047e7403 chromedriver + 3970051
# 2   chromedriver                        0x0000000104482038 chromedriver + 409656
# 3   chromedriver                        0x00000001044a8140 chromedriver + 565568
# 4   chromedriver                        0x00000001044a8376 chromedriver + 566134
# 5   chromedriver                        0x00000001044a3dd2 chromedriver + 548306
# 6   chromedriver                        0x00000001044a1836 chromedriver + 538678
# 7   chromedriver                        0x00000001044db44a chromedriver + 775242
# 8   chromedriver                        0x00000001044d5683 chromedriver + 751235
# 9   chromedriver                        0x00000001044aba45 chromedriver + 580165
# 10  chromedriver                        0x00000001044aca95 chromedriver + 584341
# 11  chromedriver                        0x000000010482c55d chromedriver + 4253021
# 12  chromedriver                        0x00000001048313a1 chromedriver + 4273057
# 13  chromedriver                        0x000000010483616f chromedriver + 4292975
# 14  chromedriver                        0x0000000104831dea chromedriver + 4275690
# 15  chromedriver                        0x000000010480b54f chromedriver + 4117839
# 16  chromedriver                        0x000000010484bed8 chromedriver + 4382424
# 17  chromedriver                        0x000000010484c05f chromedriver + 4382815
# 18  chromedriver                        0x00000001048628d5 chromedriver + 4475093
# 19  libsystem_pthread.dylib             0x00007ff8046214f4 _pthread_start + 125
# 20  libsystem_pthread.dylib             0x00007ff80461d00f thread_start + 15
