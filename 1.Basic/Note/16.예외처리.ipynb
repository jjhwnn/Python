# %%
# try catch 문

try:
    print(4 / 0)
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    f = open("./Data/test.txt", "r")
except FileNotFoundError as e:
    print(e)
else:
    data = f.read()
    f.close()
# Out:
# error

# %%
try:
    f = open("./Data/test.txt", "r")
except FileNotFoundError as e:
    pass    # 크롤링 할때 많이 사용됨
else:
    data = f.read()
    f.close()
