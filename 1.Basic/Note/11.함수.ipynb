# %% [markdown]
# ---
# # 람다(lambda) 함수
# - 보통 함수를 한줄로 간결하게 만들때 사용
# - return 명령어가 필요 없다.

# %%
def addFunction(a, b):
    return a + b

# %%
addFunction(10, 20)
# Out:
# 30

# %%
addLambda = lambda a, b: a + b
addLambda(10, 20)
# Out:
# 30
